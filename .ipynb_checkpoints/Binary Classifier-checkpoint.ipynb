# %% [markdown]
# https://medium.com/techiepedia/binary-image-classifier-cnn-using-tensorflow-a3f5d6746697
#
# DataSet: https://www.kaggle.com/datasets/d4rklucif3r/cat-and-dogs?select=dataset

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
import cv2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %%
train = ImageDataGenerator(rescale=1/255)
test = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory("C:/Users/User/FYP/CatsAndDogs/dataset/training_set/",target_size=(150,150),batch_size = 32,class_mode = 'binary')
                                         
test_dataset = test.flow_from_directory("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/",target_size=(150,150),batch_size =32,class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.
# Found 2000 images belonging to 2 classes.

# %%
test_dataset.class_indices
# Out:
# {'cats': 0, 'dogs': 1}

# %%
model = keras.Sequential()

# Convolutional layer and maxpool layer 1
model.add(keras.layers.Conv2D(32,(3,3),activation='relu',input_shape=(150,150,3)))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 2
model.add(keras.layers.Conv2D(64,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 3
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# Convolutional layer and maxpool layer 4
model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
model.add(keras.layers.MaxPool2D(2,2))

# This layer flattens the resulting image array to 1D array
model.add(keras.layers.Flatten())

# Hidden layer with 512 neurons and Rectified Linear Unit activation function 
model.add(keras.layers.Dense(512,activation='relu'))

# Output layer with single neuron which gives 0 for Cat or 1 for Dog 
# Here we use sigmoid activation function which makes our model output to lie between 0 and 1
model.add(keras.layers.Dense(1,activation='sigmoid'))

# %%
# Compiling the model
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
#steps_per_epoch = train_imagesize/batch_size

model.fit_generator(train_dataset,
         steps_per_epoch = 250,
         epochs = 10,
         validation_data = test_dataset
       
         )
# Out:
# Epoch 1/10
# C:\Users\User\AppData\Local\Temp\ipykernel_16264\1870411544.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model.fit_generator(train_dataset,
# 250/250 [==============================] - 95s 375ms/step - loss: 0.6511 - accuracy: 0.6028 - val_loss: 0.5990 - val_accuracy: 0.6530
# Epoch 2/10
# 250/250 [==============================] - 96s 382ms/step - loss: 0.5921 - accuracy: 0.6812 - val_loss: 0.5699 - val_accuracy: 0.7160
# Epoch 3/10
# 250/250 [==============================] - 102s 406ms/step - loss: 0.5385 - accuracy: 0.7293 - val_loss: 0.5322 - val_accuracy: 0.7415
# Epoch 4/10
# 250/250 [==============================] - 102s 407ms/step - loss: 0.4906 - accuracy: 0.7574 - val_loss: 0.5348 - val_accuracy: 0.7355
# Epoch 5/10
# 250/250 [==============================] - 97s 390ms/step - loss: 0.4472 - accuracy: 0.7924 - val_loss: 0.4716 - val_accuracy: 0.7775
# ...

# %%
def predictImage(filename):
    img1 = image.load_img(filename,target_size=(150,150))
    
    plt.imshow(img1)
 
    Y = image.img_to_array(img1)
    
    X = np.expand_dims(Y,axis=0)
    val = model.predict(X)
    print(val)
    if val == 1:
        
        plt.xlabel("DOG",fontsize=30)
        
    
    elif val == 0:
        
        plt.xlabel("CAT",fontsize=30)

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/cats/cat.4017.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[6.3207955e-38]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/cats/cat.4002.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[0.00032633]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/cats/cat.4003.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1.]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/cats/cat.4004.jpg")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[3.2073975e-09]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/dogs/dog.4001.jpg")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[1.6217247e-37]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/dogs/dog.4002.jpg")
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[1.]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/dogs/dog.4003.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1.]]

# %%
predictImage("C:/Users/User/FYP/CatsAndDogs/dataset/test_set/dogs/dog.4004.jpg")
# Out:
# 1/1 [==============================] - 0s 17ms/step
# [[1.]]
